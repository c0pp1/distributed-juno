# %%
from dask.distributed import Client, SSHCluster
import sys
import dask
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import dask.dataframe as dd
import dask.array as da
import dask.bag as db
import matplotlib.pyplot as plt

from dask import delayed
from time import time

# %%
# ------ ALGORITHM FUNCTIONS
def load(path):
    return np.load(path, allow_pickle=True)["a"]

def R_yz(theta_rot, phi_rot):
    return np.array([[np.cos(phi_rot) * np.cos(theta_rot), -np.sin(phi_rot) * np.cos(theta_rot), np.sin(theta_rot)], 
                     [np.sin(phi_rot), np.cos(phi_rot), 0], 
                     [-np.sin(theta_rot) * np.cos(phi_rot), np.sin(theta_rot) * np.sin(phi_rot), np.cos(theta_rot)]])

def convert_pmt_ids(input_ids, conversion_ids):
    cd_ids  = np.array(conversion_ids["CdID"])
    pmt_ids = np.array(conversion_ids["PMTID"])
    mask    = np.isin(cd_ids, input_ids)
    return pmt_ids[mask]

def find_pmt_coord(pmt_positions, data_pmt_id):
    return pmt_positions[
        np.isin(pmt_positions.PMTID, data_pmt_id)
        ].loc[:, ["x", "y", "z"]].reset_index(drop=True).to_numpy()

# ------ DASK FUNCTIONS
def load_bag(path, Nevents):
    data_np = load(path)
    data_np = data_np[:, :Nevents]
    return [np.vstack([ data_np[j, i] for j in range(3)]) for i in range(data_np.shape[1])]


# ------ DISTRIBUTED ALGORITHM FUNCTIONS
def rotate_ev(data):

    nonzeros_inds = data[2] != 0.0
    data_pmt_id   = convert_pmt_ids(data[0][nonzeros_inds], conversion_ids)
    pmt_coord     = find_pmt_coord(pmt_positions, data_pmt_id)

    tot_charge = sum(data[1][nonzeros_inds])
    x_cc       = sum(pmt_coord[:,0] * data[1][nonzeros_inds]) / tot_charge
    y_cc       = sum(pmt_coord[:,1] * data[1][nonzeros_inds]) / tot_charge
    z_cc       = sum(pmt_coord[:,2] * data[1][nonzeros_inds]) / tot_charge

    theta_cc   = np.arctan2(
        np.sqrt((x_cc)**2+(y_cc)**2), z_cc
    )
    phi_cc     = np.arctan2(y_cc, x_cc) 

    theta_rot = -theta_cc + np.pi/2
    phi_rot   = -phi_cc
    
    # coord_new = np.matmul(R_yz(theta_rot, phi_rot), pmt_coord.T)
    coord_new = np.matmul(
        R_yz(theta_rot, phi_rot), pmt_coord.T
    )

    R = np.sqrt(np.sum(np.power(coord_new, 2), axis=0))

    charge_hitt = np.vstack([data[1], data[2]])
    charge_hitt = charge_hitt[:,nonzeros_inds]

    rotated = np.vstack([coord_new, R, charge_hitt])
    
    del coord_new
    del charge_hitt
    del pmt_coord
    
    return rotated

def mapping_single_event(rotated_ev):
    ####################
    # rotated_ev must be computed
    ####################
    
    N_max = 115
    
    coord_new   = rotated_ev[:3]
    charge_hitt = rotated_ev[4:, ].T
    R           = rotated_ev[3, ].mean()

    z_levels, step = np.linspace(coord_new[2,].min(), coord_new[2,].max(), 124, retstep=True)
    #z_levels       = z_levels.persist()
    image_mat      = np.zeros((230,124,2))

    #masks = 

    for j, z in enumerate(z_levels):
        mask = (np.abs(coord_new[2,] - z) < step)         #(np.abs(pmt_pos.z - z) < delta)
        if(not np.any(mask)): continue
        masked = coord_new[:,mask]


        Rz = (R**2 - z**2)
        Neff = 0 if Rz < 0 else N_max * np.sqrt(Rz) / R
        #ix = np.zeros(np.sum(mask), dtype=np.int32)
        ix = np.around( Neff * (np.arctan2(masked[1,], masked[0,]) / np.pi) + (N_max / 2) ) + 57
        ix = ix.astype(np.int32)
        #ix = ix.compute()
        if(np.any(ix >= 230)):
            ix[ix >= 230] = ix[ix >= 230] - 230

        image_mat[ix, j,] = charge_hitt[mask, ]

                # if np.isnan(mat[ix, i+1]):
                #     mat[ix, i+1] = row.id
                # else:
                #     mat[ix, 123 if i else i] = row.id

    del rotated_ev
    return image_mat

# %%
###############################################################################################################
data_folder       = "/root/data/data/real/train/data/"
pmt_pos_fname     = "/root/distributed-juno/cluster/PMTPos_CD_LPMT.csv"
pmt_id_conv_fname = "/root/distributed-juno/cluster/PMT_ID_conversion.csv"
train_data_fname  = "raw_data_train_4.npz"


pmt_positions     = pd.read_csv(pmt_pos_fname)
pmt_id_conversion = pd.read_csv(pmt_id_conv_fname)
conversion_ids    = pd.read_csv(pmt_id_conv_fname)



Nevents    = 1024

ips        = ["10.67.22.39", "10.67.22.74", "10.67.22.27", "10.67.22.91", "10.67.22.60"]
ssh_opt    = {"known_hosts": "/root/.ssh/known_hosts"}
sched_port = {"dashboard_address": ":8787"}

n_w        = 1
n_t        = 4
n_p        = 4*n_w

worker_par = {"nthreads": n_t, "n_workers": n_w}
 

worker_par = {"nthreads": int(n_t), "n_workers": int(n_w)}

cluster = SSHCluster(
    ips,
    connect_options   = ssh_opt,
    worker_options    = worker_par,
    scheduler_options = sched_port
)
client = Client(cluster)


#################################
time_0  = time()

start   = time()
data_db = db.from_sequence(load_bag(data_folder + train_data_fname, Nevents=Nevents), npartitions=n_p)
stop    = time()

load_time = stop-start
print("Load time:\t", load_time)

start   = time()
rotated = db.map(rotate_ev, data_db)
stop    = time()

rotation_time = stop-start
#            print("Rotation time:\t", rotation_time)

start   = time()
mapped  = db.map(mapping_single_event, rotated)
stop    = time()

projection_time = stop-start
#            print("Mapping time:\t", projection_time)

start   = time()
images  = mapped.compute()
stop    = time()

compute_time = stop-start
print("Compute time:\t", compute_time)



time_1 = time()
total_time = time_1 - time_0
print("\n\nTotal time:\t", total_time)
#################################

client.shutdown()
client.close()

        
###############################################################################################################
###############################################################################################################
###############################################################################################################
###############################################################################################################
# Out:
# 2022-07-10 09:42:36,173 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:36,172 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2022-07-10 09:42:36,228 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:36,226 - distributed.scheduler - INFO - State start
# 2022-07-10 09:42:36,231 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:36,230 - distributed.scheduler - INFO - Clear task state
# 2022-07-10 09:42:36,235 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:36,231 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.39:38379
# 2022-07-10 09:42:37,935 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:37,933 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.91:39869'
# 2022-07-10 09:42:38,051 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:38,048 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.74:40297'
# 2022-07-10 09:42:38,496 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:38,493 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.91:37065
# 2022-07-10 09:42:38,608 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:38,604 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.74:43141
# 2022-07-10 09:42:38,718 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:38,717 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.27:33973'
# 2022-07-10 09:42:38,779 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:38,772 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.60:36237'
# 2022-07-10 09:42:39,745 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:39,743 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.27:40461
# 2022-07-10 09:42:39,835 - distributed.deploy.ssh - INFO - 2022-07-10 09:42:39,827 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.60:36625
# Load time:	 7.08432674407959
# Compute time:	 10.839243650436401
#
#
# Total time:	 17.95048189163208
# 2022-07-10 09:42:58,927 - distributed.client - ERROR -
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/core.py", line 291, in connect
#     comm = await asyncio.wait_for(
#   File "/root/anaconda3/envs/dask2/lib/python3.10/asyncio/tasks.py", line 445, in wait_for
#     return fut.result()
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 467, in connect
#     convert_stream_closed_error(self, e)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 148, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x7f6ddfd7a7d0>: ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/utils.py", line 776, in wrapper
#     return await func(*args, **kwargs)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1211, in _reconnect
#     await self._ensure_connected(timeout=timeout)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1241, in _ensure_connected
#     comm = await connect(
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/core.py", line 315, in connect
#     await asyncio.sleep(backoff)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/asyncio/tasks.py", line 605, in sleep
#     return await future
# asyncio.exceptions.CancelledError
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 229, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1392, in _handle_report
#     msgs = await self.scheduler_comm.comm.read()
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 245, in read
#     convert_stream_closed_error(self, e)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 150, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Client->Scheduler local=tcp://10.67.22.39:58516 remote=tcp://10.67.22.39:38379>: Stream is closed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/utils.py", line 776, in wrapper
#     return await func(*args, **kwargs)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1400, in _handle_report
#     await self._reconnect()
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/utils.py", line 776, in wrapper
#     return await func(*args, **kwargs)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1211, in _reconnect
#     await self._ensure_connected(timeout=timeout)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1241, in _ensure_connected
#     comm = await connect(
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/core.py", line 315, in connect
#     await asyncio.sleep(backoff)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/asyncio/tasks.py", line 605, in sleep
#     return await future
# asyncio.exceptions.CancelledError

# %%
###############################################################################################################
data_folder       = "/root/data/data/real/train/data/"
pmt_pos_fname     = "/root/distributed-juno/cluster/PMTPos_CD_LPMT.csv"
pmt_id_conv_fname = "/root/distributed-juno/cluster/PMT_ID_conversion.csv"
train_data_fname  = "raw_data_train_4.npz"


pmt_positions     = pd.read_csv(pmt_pos_fname)
pmt_id_conversion = pd.read_csv(pmt_id_conv_fname)
conversion_ids    = pd.read_csv(pmt_id_conv_fname)



Nevents    = 1024

ips        = ["10.67.22.39", "10.67.22.74", "10.67.22.27", "10.67.22.91", "10.67.22.60"]
ssh_opt    = {"known_hosts": "/root/.ssh/known_hosts"}
sched_port = {"dashboard_address": ":8787"}

n_w        = 4
n_t        = 1
n_p        = 4*n_w

worker_par = {"nthreads": n_t, "n_workers": n_w}
 

worker_par = {"nthreads": int(n_t), "n_workers": int(n_w)}

cluster = SSHCluster(
    ips,
    connect_options   = ssh_opt,
    worker_options    = worker_par,
    scheduler_options = sched_port
)
client = Client(cluster)


#################################
time_0  = time()

start   = time()
data_db = db.from_sequence(load_bag(data_folder + train_data_fname, Nevents=Nevents), npartitions=n_p)
stop    = time()

load_time = stop-start
print("Load time:\t", load_time)

start   = time()
rotated = db.map(rotate_ev, data_db)
stop    = time()

rotation_time = stop-start
#            print("Rotation time:\t", rotation_time)

start   = time()
mapped  = db.map(mapping_single_event, rotated)
stop    = time()

projection_time = stop-start
#            print("Mapping time:\t", projection_time)

start   = time()
images  = mapped.compute()
stop    = time()

compute_time = stop-start
print("Compute time:\t", compute_time)



time_1 = time()
total_time = time_1 - time_0
print("\n\nTotal time:\t", total_time)
#################################

client.shutdown()
client.close()

        
###############################################################################################################
###############################################################################################################
###############################################################################################################
###############################################################################################################
# Out:
# 2022-07-10 09:43:03,858 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:03,857 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2022-07-10 09:43:03,918 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:03,916 - distributed.scheduler - INFO - State start
# 2022-07-10 09:43:03,921 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:03,921 - distributed.scheduler - INFO - Clear task state
# 2022-07-10 09:43:03,923 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:03,921 - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.39:44425
# 2022-07-10 09:43:05,210 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,209 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.91:43295'
# 2022-07-10 09:43:05,214 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,213 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.91:37905'
# 2022-07-10 09:43:05,215 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,215 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.91:32981'
# 2022-07-10 09:43:05,223 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,222 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.91:45289'
# 2022-07-10 09:43:05,249 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,247 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.74:33169'
# 2022-07-10 09:43:05,252 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,250 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.74:39397'
# 2022-07-10 09:43:05,254 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,252 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.74:44501'
# 2022-07-10 09:43:05,265 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,263 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.74:41901'
# 2022-07-10 09:43:05,603 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,601 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.27:44679'
# 2022-07-10 09:43:05,607 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,606 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.27:36575'
# 2022-07-10 09:43:05,612 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,610 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.27:45933'
# 2022-07-10 09:43:05,616 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,615 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.27:46535'
# 2022-07-10 09:43:05,626 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,620 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.60:43161'
# 2022-07-10 09:43:05,629 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,624 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.60:36245'
# 2022-07-10 09:43:05,638 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,632 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.60:39137'
# 2022-07-10 09:43:05,640 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,635 - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.60:46277'
# 2022-07-10 09:43:05,925 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,922 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.91:34101
# 2022-07-10 09:43:05,926 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,922 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.91:34101
# 2022-07-10 09:43:05,927 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,922 - distributed.worker - INFO -          dashboard at:          10.67.22.91:43031
# 2022-07-10 09:43:05,928 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,923 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:05,931 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,923 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:05,932 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,923 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:05,933 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,923 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:05,934 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,923 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-d9ki6xag
# 2022-07-10 09:43:05,935 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,923 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:05,941 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,938 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.91:44841
# 2022-07-10 09:43:05,942 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,939 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.91:44841
# 2022-07-10 09:43:05,943 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,939 - distributed.worker - INFO -          dashboard at:          10.67.22.91:42555
# 2022-07-10 09:43:05,944 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,939 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:05,945 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,939 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:05,946 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,939 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:05,948 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,939 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:05,949 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,939 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-3i304y6_
# 2022-07-10 09:43:05,950 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,939 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:05,955 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.74:40131
# 2022-07-10 09:43:05,956 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.74:40131
# 2022-07-10 09:43:05,958 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO -          dashboard at:          10.67.22.74:34959
# 2022-07-10 09:43:05,959 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:05,960 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:05,961 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:05,962 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:05,963 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-cgmbvd_c
# 2022-07-10 09:43:05,965 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,948 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:05,970 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.91:34149
# 2022-07-10 09:43:05,971 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.91:34149
# 2022-07-10 09:43:05,972 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO -          dashboard at:          10.67.22.91:35871
# 2022-07-10 09:43:05,972 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:05,973 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:05,974 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:05,975 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:05,976 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-kiof63jw
# 2022-07-10 09:43:05,976 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,962 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:05,992 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.74:41577
# 2022-07-10 09:43:05,993 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.74:41577
# 2022-07-10 09:43:05,995 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO -          dashboard at:          10.67.22.74:42347
# 2022-07-10 09:43:05,999 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:06,000 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,001 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:06,003 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:06,004 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-f1dt_tiv
# 2022-07-10 09:43:06,005 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,989 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,013 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.91:44657
# 2022-07-10 09:43:06,014 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,993 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.74:42535
# 2022-07-10 09:43:06,016 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.74:42535
# 2022-07-10 09:43:06,017 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO -          dashboard at:          10.67.22.74:34435
# 2022-07-10 09:43:06,019 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:06,020 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,021 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:06,023 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:06,024 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-0kr9u6e9
# 2022-07-10 09:43:06,026 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:05,994 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,060 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,054 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.74:43435
# 2022-07-10 09:43:06,615 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,611 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.27:41793
# 2022-07-10 09:43:06,617 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,611 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.27:41793
# 2022-07-10 09:43:06,619 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,611 - distributed.worker - INFO -          dashboard at:          10.67.22.27:40767
# 2022-07-10 09:43:06,620 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,611 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:06,620 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,611 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,621 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,612 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:06,626 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,612 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:06,627 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,612 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-9h4hxgps
# 2022-07-10 09:43:06,628 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,611 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.27:38913
# 2022-07-10 09:43:06,629 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,612 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,630 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,612 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.27:38913
# 2022-07-10 09:43:06,631 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,612 - distributed.worker - INFO -          dashboard at:          10.67.22.27:40307
# 2022-07-10 09:43:06,632 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,612 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:06,633 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,612 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,633 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,613 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:06,635 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,613 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:06,636 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,613 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-3s8j7dy5
# 2022-07-10 09:43:06,637 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,613 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,641 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.27:44627
# 2022-07-10 09:43:06,642 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.27:44627
# 2022-07-10 09:43:06,643 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO -          dashboard at:          10.67.22.27:44211
# 2022-07-10 09:43:06,644 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:06,645 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,646 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:06,646 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:06,647 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-wswnmx2z
# 2022-07-10 09:43:06,648 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,633 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,654 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,638 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.27:38221
# 2022-07-10 09:43:06,657 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.60:42991
# 2022-07-10 09:43:06,658 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.60:42991
# 2022-07-10 09:43:06,659 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO -          dashboard at:          10.67.22.60:39541
# 2022-07-10 09:43:06,660 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:06,661 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,662 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:06,662 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:06,663 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-pu_7rmuz
# 2022-07-10 09:43:06,664 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,646 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,716 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.60:35395
# 2022-07-10 09:43:06,717 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.60:35395
# 2022-07-10 09:43:06,718 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO -          dashboard at:          10.67.22.60:40191
# 2022-07-10 09:43:06,719 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:06,724 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,725 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:06,726 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:06,726 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-q5eex28x
# 2022-07-10 09:43:06,727 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.60:34841
# 2022-07-10 09:43:06,728 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,710 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,729 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,711 - distributed.worker - INFO -          Listening to:    tcp://10.67.22.60:34841
# 2022-07-10 09:43:06,730 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,711 - distributed.worker - INFO -          dashboard at:          10.67.22.60:46355
# 2022-07-10 09:43:06,730 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,711 - distributed.worker - INFO - Waiting to connect to:    tcp://10.67.22.39:44425
# 2022-07-10 09:43:06,731 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,711 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,732 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,711 - distributed.worker - INFO -               Threads:                          1
# 2022-07-10 09:43:06,733 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,711 - distributed.worker - INFO -                Memory:                   1.94 GiB
# 2022-07-10 09:43:06,734 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,711 - distributed.worker - INFO -       Local Directory: /root/dask-worker-space/worker-x7yqg6mo
# 2022-07-10 09:43:06,734 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,712 - distributed.worker - INFO - -------------------------------------------------
# 2022-07-10 09:43:06,760 - distributed.deploy.ssh - INFO - 2022-07-10 09:43:06,753 - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.60:35759
# Load time:	 6.029345750808716
# Compute time:	 4.3050971031188965
#
#
# Total time:	 10.357610702514648
# 2022-07-10 09:43:18,276 - distributed.client - ERROR -
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/core.py", line 291, in connect
#     comm = await asyncio.wait_for(
#   File "/root/anaconda3/envs/dask2/lib/python3.10/asyncio/tasks.py", line 445, in wait_for
#     return fut.result()
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 467, in connect
#     convert_stream_closed_error(self, e)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 148, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x7f6ddfd79cf0>: ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/utils.py", line 776, in wrapper
#     return await func(*args, **kwargs)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1211, in _reconnect
#     await self._ensure_connected(timeout=timeout)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1241, in _ensure_connected
#     comm = await connect(
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/core.py", line 315, in connect
#     await asyncio.sleep(backoff)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/asyncio/tasks.py", line 605, in sleep
#     return await future
# asyncio.exceptions.CancelledError
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 229, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1392, in _handle_report
#     msgs = await self.scheduler_comm.comm.read()
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 245, in read
#     convert_stream_closed_error(self, e)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/tcp.py", line 150, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Client->Scheduler local=tcp://10.67.22.39:37922 remote=tcp://10.67.22.39:44425>: Stream is closed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/utils.py", line 776, in wrapper
#     return await func(*args, **kwargs)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1400, in _handle_report
#     await self._reconnect()
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/utils.py", line 776, in wrapper
#     return await func(*args, **kwargs)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1211, in _reconnect
#     await self._ensure_connected(timeout=timeout)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/client.py", line 1241, in _ensure_connected
#     comm = await connect(
#   File "/root/anaconda3/envs/dask2/lib/python3.10/site-packages/distributed/comm/core.py", line 315, in connect
#     await asyncio.sleep(backoff)
#   File "/root/anaconda3/envs/dask2/lib/python3.10/asyncio/tasks.py", line 605, in sleep
#     return await future
# asyncio.exceptions.CancelledError
