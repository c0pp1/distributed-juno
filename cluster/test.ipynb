# %%
from dask.distributed import Client, SSHCluster
import sys

# %%
cluster = SSHCluster(
    ["10.67.22.39", "10.67.22.74", "10.67.22.27", "10.67.22.91", "10.67.22.60"],
    connect_options={"known_hosts": "/root/.ssh/known_hosts"},
    #worker_options={"nthreads": 2},
    scheduler_options={"dashboard_address": ":1234"}
)
# Out:
# distributed.deploy.ssh - INFO - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# distributed.deploy.ssh - INFO - distributed.scheduler - INFO - Clear task state
# distributed.deploy.ssh - INFO - distributed.scheduler - INFO -   Scheduler at:   tcp://10.67.22.39:33287
# distributed.deploy.ssh - INFO - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.91:39171'
# distributed.deploy.ssh - INFO - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.74:35397'
# distributed.deploy.ssh - INFO - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.91:34519
# distributed.deploy.ssh - INFO - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.27:34557'
# distributed.deploy.ssh - INFO - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.74:35997
# distributed.deploy.ssh - INFO - distributed.nanny - INFO -         Start Nanny at: 'tcp://10.67.22.60:34049'
# distributed.deploy.ssh - INFO - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.27:35723
# distributed.deploy.ssh - INFO - distributed.worker - INFO -       Start worker at:    tcp://10.67.22.60:40073

# %%
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://10.67.22.39:33287' processes=4 threads=16, memory=31.08 GiB>

# %%
client.shutdown()

# %%
client.run_on_scheduler(lambda dask_scheduler=None: 
    dask_scheduler.close() & sys.exit(0))
# Out:
# ---------------------------------------------------------------------------
# StreamClosedError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/distributed/comm/tcp.py:211, in TCP.read(self, deserializers)
#     210 try:
# --> 211     frames_nbytes = await stream.read_bytes(fmt_size)
#     212     (frames_nbytes,) = struct.unpack(fmt, frames_nbytes)
#
# StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# CommClosedError                           Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 client.run_on_scheduler(lambda dask_scheduler=None:
#       2     dask_scheduler.close() & sys.exit(0))
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/client.py:2633, in Client.run_on_scheduler(self, function, *args, **kwargs)
#    2595 def run_on_scheduler(self, function, *args, **kwargs):
#    2596     """Run a function on the scheduler process
#    2597
#    2598     This is typically used for live debugging.  The function should take a
#    (...)
#    2631     Client.start_ipython_scheduler : Start an IPython session on scheduler
#    2632     """
# -> 2633     return self.sync(self._run_on_scheduler, function, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/utils.py:311, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     309     return future
#     310 else:
# --> 311     return sync(
#     312         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     313     )
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/utils.py:378, in sync(loop, func, callback_timeout, *args, **kwargs)
#     376 if error:
#     377     typ, exc, tb = error
# --> 378     raise exc.with_traceback(tb)
#     379 else:
#     380     return result
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/utils.py:351, in sync.<locals>.f()
#     349         future = asyncio.wait_for(future, callback_timeout)
#     350     future = asyncio.ensure_future(future)
# --> 351     result = yield future
#     352 except Exception:
#     353     error = sys.exc_info()
#
# File ~/anaconda3/lib/python3.9/site-packages/tornado/gen.py:762, in Runner.run(self)
#     759 exc_info = None
#     761 try:
# --> 762     value = future.result()
#     763 except Exception:
#     764     exc_info = sys.exc_info()
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/client.py:2583, in Client._run_on_scheduler(self, function, wait, *args, **kwargs)
#    2582 async def _run_on_scheduler(self, function, *args, wait=True, **kwargs):
# -> 2583     response = await self.scheduler.run_function(
#    2584         function=dumps(function, protocol=4),
#    2585         args=dumps(args, protocol=4),
#    2586         kwargs=dumps(kwargs, protocol=4),
#    2587         wait=wait,
#    2588     )
#    2589     if response["status"] == "error":
#    2590         typ, exc, tb = clean_exception(**response)
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/core.py:922, in PooledRPCCall.__getattr__.<locals>.send_recv_from_rpc(**kwargs)
#     920 prev_name, comm.name = comm.name, "ConnectionPool." + key
#     921 try:
# --> 922     return await send_recv(comm=comm, op=key, **kwargs)
#     923 finally:
#     924     self.pool.reuse(self.addr, comm)
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/core.py:691, in send_recv(comm, reply, serializers, deserializers, **kwargs)
#     689 await comm.write(msg, serializers=serializers, on_error="raise")
#     690 if reply:
# --> 691     response = await comm.read(deserializers=deserializers)
#     692 else:
#     693     response = None
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/comm/tcp.py:227, in TCP.read(self, deserializers)
#     225     self._closed = True
#     226     if not sys.is_finalizing():
# --> 227         convert_stream_closed_error(self, e)
#     228 except Exception:
#     229     # Some OSError or a another "low-level" exception. We do not really know what
#     230     # was already read from the underlying socket, so it is not even safe to retry
#     231     # here using the same stream. The only safe thing to do is to abort.
#     232     # (See also GitHub #4133).
#     233     self.abort()
#
# File ~/anaconda3/lib/python3.9/site-packages/distributed/comm/tcp.py:135, in convert_stream_closed_error(obj, exc)
#     133     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
#     134 else:
# --> 135     raise CommClosedError(f"in {obj}: {exc}") from exc
#
# CommClosedError: in <TCP (closed) ConnectionPool.run_function local=tcp://10.67.22.39:56322 remote=tcp://10.67.22.39:38407>: Stream is closed
