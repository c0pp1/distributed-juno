# %%
from dask.distributed import Client, SSHCluster
import sys
import dask
import pandas as pd
import numpy as np
from tqdm import tqdm
import dask.dataframe as dd
import dask.array as da
import dask.bag as db
import matplotlib.pyplot as plt
from dask import delayed

# %%
CLUSTER_TYPE ="local"
# %env CLUSTER_TYPE $CLUSTER_TYPE
# Out:
# env: CLUSTER_TYPE=local

# %%
# %%script bash --bg --out script_out
#
# if [[ "$CLUSTER_TYPE" != "docker_cluster" ]]; then
#     echo "Launching scheduler and worker"
#
#     HOSTIP=`hostname -I | xargs`
#
#     echo "dask-scheduler --host $HOSTIP --dashboard-address $HOSTIP:8787"
#
#     # dask scheduler
#     dask-scheduler --host $HOSTIP --dashboard-address $HOSTIP:8787 &
#
#     # dask worker
#     dask-worker $HOSTIP:8786 --memory-limit 4GB --nworkers 4 --nthreads 2 &
#
# fi

# %%
host_ip = !hostname -I | xargs
host_ip = host_ip[0]

from dask.distributed import Client

if CLUSTER_TYPE == "local":
    
    client = Client()

elif CLUSTER_TYPE == "docker_container":
    
    client = Client("{}:8786".format(host_ip))
    
elif CLUSTER_TYPE == "docker_cluster":
    
    # use the provided master
    client = Client("dask-scheduler:8786")
    
client
# Out:
# <Client: 'tcp://127.0.0.1:53844' processes=4 threads=8, memory=16.00 GiB>

# %%
def load(path):
    return np.load(path, allow_pickle=True)["a"]

@delayed    
def R_yz(theta_rot, phi_rot):
    return np.array([[np.cos(phi_rot) * np.cos(theta_rot), -np.sin(phi_rot) * np.cos(theta_rot), np.sin(theta_rot)], 
                     [np.sin(phi_rot), np.cos(phi_rot), 0], 
                     [-np.sin(theta_rot) * np.cos(phi_rot), np.sin(theta_rot) * np.sin(phi_rot), np.cos(theta_rot)]])

@delayed
def convert_pmt_ids(input_ids, conversion_ids):
    cd_ids  = np.array(conversion_ids["CdID"])
    pmt_ids = np.array(conversion_ids["PMTID"])
    mask    = np.isin(cd_ids, input_ids)
    return pmt_ids[mask]

@delayed
def find_pmt_coord(pmt_positions, data_pmt_id):
    return pmt_positions[
        np.isin(pmt_positions.PMTID, data_pmt_id)
        ].loc[:, ['x', 'y', 'z']].reset_index(drop=True)

# %%
data_folder       = "../data/"
pmt_pos_fname     = "PMTPos_CD_LPMT.csv"
pmt_id_conv_fname = "PMT_ID_conversion.csv"
train_data_fname  = "raw_data_train_4.npz"

# %%
pmt_positions     = pd.read_csv(data_folder+pmt_pos_fname)
pmt_id_conversion = pd.read_csv(data_folder+pmt_id_conv_fname)
conversion_ids    = pd.read_csv(data_folder+pmt_id_conv_fname)

# %%
N_max = 115

error_ls = []
def rotate_single_file(fname):

    data_np = load(data_folder+train_data_fname) # dask.delayed(load)(data_folder+train_data_fname).compute()
    Nevents = 10 # data_np.shape[1]
    rotated = []

    for i in range(Nevents):
        # find non-zero-time hits
        data = da.from_array([data_np[:,i][j] for j in range(3)])
        nonzeros_inds = data[2] != 0.0
        data_pmt_id   = convert_pmt_ids(data[0][nonzeros_inds], conversion_ids)
        pmt_coord     = find_pmt_coord(pmt_positions, data_pmt_id)
        
        tot_charge = dask.delayed(sum)(data[1][nonzeros_inds])
        x_cc       = dask.delayed(sum)(pmt_coord[:,0] * data[1][nonzeros_inds]) / tot_charge
        y_cc       = dask.delayed(sum)(pmt_coord[:,1] * data[1][nonzeros_inds]) / tot_charge
        z_cc       = dask.delayed(sum)(pmt_coord[:,2] * data[1][nonzeros_inds]) / tot_charge
        
        theta_cc   = dask.delayed(da.arctan2)(
            dask.delayed(da.sqrt)((x_cc)**2+(y_cc)**2), z_cc
        )
        phi_cc     = dask.delayed(da.arctan2)(y_cc, x_cc) 
        
        theta_rot = -theta_cc + np.pi/2
        phi_rot   = -phi_cc
        
        # coord_new = np.matmul(R_yz(theta_rot, phi_rot), pmt_coord.T)
        coord_new = dask.delayed(da.matmul)(
            R_yz(theta_rot, phi_rot), pmt_coord.T
        )

        R = dask.delayed(da.sqrt)(dask.delayed(da.sum)(dask.delayed(da.power)(coord_new, 2), axis=0))

        charge_hitt = da.vstack([data[1], data[2]])
        charge_hitt = charge_hitt[:,nonzeros_inds]

        rotated.append(dask.delayed(da.vstack)([coord_new, R, charge_hitt]))
        del coord_new
        del charge_hitt
        del pmt_coord
    
    return rotated

def mapping_single_event(rotated_ev):
        ####################
        # rotated_ev must be computed
        ####################
    coord_new   = rotated_ev[:3]
    charge_hitt = rotated_ev[4:, ].T
    R           = rotated_ev[3,].mean()

    z_levels, step = da.linspace(coord_new[2,].min(), coord_new[2,].max(), 124, retstep=True)
    z_levels       = z_levels.persist()
    image_mat      = da.zeros((230,124,2))

    for j, z in enumerate(z_levels):
        mask = (da.abs(coord_new[2,] - z) < step)         #(np.abs(pmt_pos.z - z) < delta)
        if(not da.any(mask)): continue
        masked = coord_new[:,mask]

        Rz = (R**2 - z**2)
        Neff = 0 if Rz < 0 else N_max * da.sqrt(Rz) / R
        #ix = np.zeros(np.sum(mask), dtype=np.int32)
        ix = da.around( Neff * (da.arctan2(masked[1,], masked[0,]) / np.pi) + (N_max / 2) ) + 57
        ix = ix.astype(np.int32)
        #ix = ix.compute()
        if(da.any(ix >= 230)):
            ix[ix >= 230] = ix[ix >= 230] - 230

        image_mat[ix, j,] = charge_hitt[ix, ]

            # if np.isnan(mat[ix, i+1]):
            #     mat[ix, i+1] = row.id
            # else:
            #     mat[ix, 123 if i else i] = row.id

    del rotated_ev
    return image_mat

# %%
rotated_one_file = rotate_single_file(train_data_fname) # qui dovremo fare un client.map quando mettiamo più files

rotation_future  = client.map(dask.compute, rotated_one_file)

### !!!! ERRORE SUL GATHER

rotated          = client.gather(rotation_future)
persisted_rot    = [rotated[i][0].persist() for i in range(len(rotated))]
# Out:
# /Users/niklai/miniforge3/lib/python3.9/site-packages/distributed/worker.py:4533: UserWarning: Large object of size 1.32 MiB detected in task graph:
#   (Delayed('vstack-934e51b9-7c7a-456c-a02a-c0407d971094'),)
# Consider scattering large objects ahead of time
# with client.scatter to reduce scheduler burden and
# keep data on workers
#
#     future = client.submit(func, big_data)    # bad
#
#     big_future = client.scatter(big_data)     # good
#     future = client.submit(func, big_future)  # good
#   warnings.warn(
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0      316.0782  -882.0791  19365.0000
# 1      941.0836  1016.1627  19365.0000
# 2     -274.3375 -1908.0597  19338.1592
# 3    -1915.1156   219.7390  19338.1592
# 4     2213.9154  1066.1655  19278.0244
# ...         ...        ...         ...
# 2524  -744.5171 -1167.8695 -19365.0000
# 2525 -1273.1379   545.3989 -19365.0000
# 2526  -686.8696  -637.3219 -19365.0000
# 2527   895.3717   276.1856 -19365.0000
# 2528  -926.5345   139.6526 -19365.0000
#
# [2529 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0     -930.2976  -111.8724  19365.0
# 1     -492.5657  -797.0872  19365.0
# 2      316.0782  -882.0791  19365.0
# 3    -1001.8845  -956.3302  19365.0
# 4     1317.6029   426.9224  19365.0
# ...         ...        ...      ...
# 4310  -367.3785  1335.4299 -19365.0
# 4311 -1273.1379   545.3989 -19365.0
# 4312    70.0221  -934.3800 -19365.0
# 4313   895.3717   276.1856 -19365.0
# 4314  -926.5345   139.6526 -19365.0
#
# [4315 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 1])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0      316.0782  -882.0791  19365.0000
# 1      941.0836  1016.1627  19365.0000
# 2     -274.3375 -1908.0597  19338.1592
# 3    -1915.1156   219.7390  19338.1592
# 4     2213.9154  1066.1655  19278.0244
# ...         ...        ...         ...
# 2524  -744.5171 -1167.8695 -19365.0000
# 2525 -1273.1379   545.3989 -19365.0000
# 2526  -686.8696  -637.3219 -19365.0000
# 2527   895.3717   276.1856 -19365.0000
# 2528  -926.5345   139.6526 -19365.0000
#
# [2529 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 1])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0     -930.2976  -111.8724  19365.0
# 1     -492.5657  -797.0872  19365.0
# 2      316.0782  -882.0791  19365.0
# 3      789.6295   504.4345  19365.0
# 4    -1288.7835  -507.2101  19365.0
# ...         ...        ...      ...
# 9871   164.0672  1375.2480 -19365.0
# 9872  -367.3785  1335.4299 -19365.0
# 9873 -1273.1379   545.3989 -19365.0
# 9874   342.3245   872.2287 -19365.0
# 9875  -468.5000   811.4658 -19365.0
#
# [9876 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0     -930.2976  -111.8724  19365.0
# 1     -492.5657  -797.0872  19365.0
# 2      316.0782  -882.0791  19365.0
# 3    -1001.8845  -956.3302  19365.0
# 4     1317.6029   426.9224  19365.0
# ...         ...        ...      ...
# 4310  -367.3785  1335.4299 -19365.0
# 4311 -1273.1379   545.3989 -19365.0
# 4312    70.0221  -934.3800 -19365.0
# 4313   895.3717   276.1856 -19365.0
# 4314  -926.5345   139.6526 -19365.0
#
# [4315 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0     -930.2976  -111.8724  19365.0
# 1     -492.5657  -797.0872  19365.0
# 2      316.0782  -882.0791  19365.0
# 3      886.7088  -302.8474  19365.0
# 4      789.6295   504.4345  19365.0
# ...         ...        ...      ...
# 9064  1304.2592  -465.9751 -19365.0
# 9065  1177.5064   729.1802 -19365.0
# 9066   164.0672  1375.2480 -19365.0
# 9067  -367.3785  1335.4299 -19365.0
# 9068    70.0221  -934.3800 -19365.0
#
# [9069 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0      316.0782  -882.0791  19365.0000
# 1      941.0836  1016.1627  19365.0000
# 2     -274.3375 -1908.0597  19338.1592
# 3    -1915.1156   219.7390  19338.1592
# 4     2213.9154  1066.1655  19278.0244
# ...         ...        ...         ...
# 2524  -744.5171 -1167.8695 -19365.0000
# 2525 -1273.1379   545.3989 -19365.0000
# 2526  -686.8696  -637.3219 -19365.0000
# 2527   895.3717   276.1856 -19365.0000
# 2528  -926.5345   139.6526 -19365.0000
#
# [2529 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 0])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 0)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0     -930.2976  -111.8724  19365.0
# 1     -492.5657  -797.0872  19365.0
# 2      316.0782  -882.0791  19365.0
# 3    -1001.8845  -956.3302  19365.0
# 4     1317.6029   426.9224  19365.0
# ...         ...        ...      ...
# 4310  -367.3785  1335.4299 -19365.0
# 4311 -1273.1379   545.3989 -19365.0
# 4312    70.0221  -934.3800 -19365.0
# 4313   895.3717   276.1856 -19365.0
# 4314  -926.5345   139.6526 -19365.0
#
# [4315 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 0])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 0)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0     -930.2976  -111.8724  19365.0
# 1     -492.5657  -797.0872  19365.0
# 2      316.0782  -882.0791  19365.0
# 3      789.6295   504.4345  19365.0
# 4    -1288.7835  -507.2101  19365.0
# ...         ...        ...      ...
# 9871   164.0672  1375.2480 -19365.0
# 9872  -367.3785  1335.4299 -19365.0
# 9873 -1273.1379   545.3989 -19365.0
# 9874   342.3245   872.2287 -19365.0
# 9875  -468.5000   811.4658 -19365.0
#
# [9876 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 0])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 0)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0     -930.2976  -111.8724  19365.0
# 1     -492.5657  -797.0872  19365.0
# 2      316.0782  -882.0791  19365.0
# 3      886.7088  -302.8474  19365.0
# 4      789.6295   504.4345  19365.0
# ...         ...        ...      ...
# 9064  1304.2592  -465.9751 -19365.0
# 9065  1177.5064   729.1802 -19365.0
# 9066   164.0672  1375.2480 -19365.0
# 9067  -367.3785  1335.4299 -19365.0
# 9068    70.0221  -934.3800 -19365.0
#
# [9069 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 1])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -492.5657  -797.0872  19365.0000
# 1       97.9432   931.8670  19365.0000
# 2    -1288.7835  -507.2101  19365.0000
# 3    -1001.8845  -956.3302  19365.0000
# 4      781.2746 -1143.6061  19365.0000
# ...         ...        ...         ...
# 5658   581.1004  2387.5621 -19278.0244
# 5659 -2198.3939  1097.8134 -19278.0244
# 5660 -2457.0079    35.2485 -19278.0244
# 5661  -800.7877 -1753.4799 -19338.1593
# 5662    70.0221  -934.3800 -19365.0000
#
# [5663 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -207.7120  1369.3359  19365.0000
# 1    -1372.3538   187.0427  19365.0000
# 2      800.7874 -1753.4801  19338.1592
# 3     1420.2017 -1303.4493  19338.1592
# 4     1678.5204   947.9041  19338.1592
# ...         ...        ...         ...
# 5035   910.4179 -1043.7812 -19365.0000
# 5036   815.0244  1119.8550 -19365.0000
# 5037   164.0672  1375.2480 -19365.0000
# 5038  -686.8696  -637.3219 -19365.0000
# 5039  -926.5345   139.6526 -19365.0000
#
# [5040 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0     -930.2976  -111.8724  19365.0
# 1     -492.5657  -797.0872  19365.0
# 2      316.0782  -882.0791  19365.0
# 3      886.7088  -302.8474  19365.0
# 4      789.6295   504.4345  19365.0
# ...         ...        ...      ...
# 9064  1304.2592  -465.9751 -19365.0
# 9065  1177.5064   729.1802 -19365.0
# 9066   164.0672  1375.2480 -19365.0
# 9067  -367.3785  1335.4299 -19365.0
# 9068    70.0221  -934.3800 -19365.0
#
# [9069 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 0])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 0)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -492.5657  -797.0872  19365.0000
# 1       97.9432   931.8670  19365.0000
# 2    -1288.7835  -507.2101  19365.0000
# 3    -1001.8845  -956.3302  19365.0000
# 4      781.2746 -1143.6061  19365.0000
# ...         ...        ...         ...
# 5658   581.1004  2387.5621 -19278.0244
# 5659 -2198.3939  1097.8134 -19278.0244
# 5660 -2457.0079    35.2485 -19278.0244
# 5661  -800.7877 -1753.4799 -19338.1593
# 5662    70.0221  -934.3800 -19365.0000
#
# [5663 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 1])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -207.7120  1369.3359  19365.0000
# 1    -1372.3538   187.0427  19365.0000
# 2      800.7874 -1753.4801  19338.1592
# 3     1420.2017 -1303.4493  19338.1592
# 4     1678.5204   947.9041  19338.1592
# ...         ...        ...         ...
# 5035   910.4179 -1043.7812 -19365.0000
# 5036   815.0244  1119.8550 -19365.0000
# 5037   164.0672  1375.2480 -19365.0000
# 5038  -686.8696  -637.3219 -19365.0000
# 5039  -926.5345   139.6526 -19365.0000
#
# [5040 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 0])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 0)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -492.5657  -797.0872  19365.0000
# 1      789.6295   504.4345  19365.0000
# 2    -1001.8845  -956.3302  19365.0000
# 3     -406.9906 -1323.8518  19365.0000
# 4      123.0243 -1379.5670  19365.0000
# ...         ...        ...         ...
# 5451  2228.9814  1034.2979 -19278.0244
# 5452  1097.8136  2198.3939 -19278.0244
# 5453 -1504.3609  1942.9430 -19278.0244
# 5454 -1420.2017 -1303.4493 -19338.1592
# 5455  -686.8696  -637.3219 -19365.0000
#
# [5456 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -406.9906 -1323.8518  19365.0000
# 1      781.2746 -1143.6061  19365.0000
# 2    -1200.0962   691.3712  19365.0000
# 3     1915.1156   219.7390  19338.1592
# 4     -899.5856  1704.9043  19338.1592
# ...         ...        ...         ...
# 3198   899.5855  1704.9042 -19338.1593
# 3199 -1220.1985  -655.3286 -19365.0000
# 3200    70.0221  -934.3800 -19365.0000
# 3201   774.1857  -527.8309 -19365.0000
# 3202   342.3245   872.2287 -19365.0000
#
# [3203 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0       97.9432   931.8670  19365.0
# 1    -1001.8845  -956.3302  19365.0
# 2      123.0243 -1379.5670  19365.0
# 3     1155.2933  -763.9616  19365.0
# 4     1381.2240  -102.2017  19365.0
# ...         ...        ...      ...
# 8045  1304.2592  -465.9751 -19365.0
# 8046   164.0672  1375.2480 -19365.0
# 8047  -367.3785  1335.4299 -19365.0
# 8048    70.0221  -934.3800 -19365.0
# 8049   342.3245   872.2287 -19365.0
#
# [8050 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -406.9906 -1323.8518  19365.0000
# 1      781.2746 -1143.6061  19365.0000
# 2    -1200.0962   691.3712  19365.0000
# 3     1915.1156   219.7390  19338.1592
# 4     -899.5856  1704.9043  19338.1592
# ...         ...        ...         ...
# 3198   899.5855  1704.9042 -19338.1593
# 3199 -1220.1985  -655.3286 -19365.0000
# 3200    70.0221  -934.3800 -19365.0000
# 3201   774.1857  -527.8309 -19365.0000
# 3202   342.3245   872.2287 -19365.0000
#
# [3203 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 1])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -492.5657  -797.0872  19365.0000
# 1       97.9432   931.8670  19365.0000
# 2    -1288.7835  -507.2101  19365.0000
# 3    -1001.8845  -956.3302  19365.0000
# 4      781.2746 -1143.6061  19365.0000
# ...         ...        ...         ...
# 5658   581.1004  2387.5621 -19278.0244
# 5659 -2198.3939  1097.8134 -19278.0244
# 5660 -2457.0079    35.2485 -19278.0244
# 5661  -800.7877 -1753.4799 -19338.1593
# 5662    70.0221  -934.3800 -19365.0000
#
# [5663 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 0])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 0)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-934e51b9-7c7a-456c-a02a-c0407d971094'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-16d48527-eccb-42ef-98c8-249a7681adac'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-a4d257ba-1395-4224-9776-4c493f6e58e6'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -406.9906 -1323.8518  19365.0000
# 1      781.2746 -1143.6061  19365.0000
# 2    -1200.0962   691.3712  19365.0000
# 3     1915.1156   219.7390  19338.1592
# 4     -899.5856  1704.9043  19338.1592
# ...         ...        ...         ...
# 3198   899.5855  1704.9042 -19338.1593
# 3199 -1220.1985  -655.3286 -19365.0000
# 3200    70.0221  -934.3800 -19365.0000
# 3201   774.1857  -527.8309 -19365.0000
# 3202   342.3245   872.2287 -19365.0000
#
# [3203 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 0])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 0)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y        z
# 0       97.9432   931.8670  19365.0
# 1    -1001.8845  -956.3302  19365.0
# 2      123.0243 -1379.5670  19365.0
# 3     1155.2933  -763.9616  19365.0
# 4     1381.2240  -102.2017  19365.0
# ...         ...        ...      ...
# 8045  1304.2592  -465.9751 -19365.0
# 8046   164.0672  1375.2480 -19365.0
# 8047  -367.3785  1335.4299 -19365.0
# 8048    70.0221  -934.3800 -19365.0
# 8049   342.3245   872.2287 -19365.0
#
# [8050 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 1])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -492.5657  -797.0872  19365.0000
# 1      789.6295   504.4345  19365.0000
# 2    -1001.8845  -956.3302  19365.0000
# 3     -406.9906 -1323.8518  19365.0000
# 4      123.0243 -1379.5670  19365.0000
# ...         ...        ...         ...
# 5451  2228.9814  1034.2979 -19278.0244
# 5452  1097.8136  2198.3939 -19278.0244
# 5453 -1504.3609  1942.9430 -19278.0244
# 5454 -1420.2017 -1303.4493 -19338.1592
# 5455  -686.8696  -637.3219 -19365.0000
#
# [5456 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 1])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-63d94ff6-5949-40a0-9593-7722de2bc10b'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -492.5657  -797.0872  19365.0000
# 1      789.6295   504.4345  19365.0000
# 2      941.0836  1016.1627  19365.0000
# 3    -1200.0962   691.3712  19365.0000
# 4     -382.8191  1889.2863  19338.1592
# ...         ...        ...         ...
# 5836  -686.8696  -637.3219 -19365.0000
# 5837    70.0221  -934.3800 -19365.0000
# 5838   774.1857  -527.8309 -19365.0000
# 5839   895.3717   276.1856 -19365.0000
# 5840  -926.5345   139.6526 -19365.0000
#
# [5841 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 2])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -492.5657  -797.0872  19365.0000
# 1      789.6295   504.4345  19365.0000
# 2      941.0836  1016.1627  19365.0000
# 3    -1200.0962   691.3712  19365.0000
# 4     -382.8191  1889.2863  19338.1592
# ...         ...        ...         ...
# 5836  -686.8696  -637.3219 -19365.0000
# 5837    70.0221  -934.3800 -19365.0000
# 5838   774.1857  -527.8309 -19365.0000
# 5839   895.3717   276.1856 -19365.0000
# 5840  -926.5345   139.6526 -19365.0000
#
# [5841 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 0])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 0)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  execute_task
# args:      ((<built-in function getitem>,               x          y           z
# 0     -492.5657  -797.0872  19365.0000
# 1      789.6295   504.4345  19365.0000
# 2      941.0836  1016.1627  19365.0000
# 3    -1200.0962   691.3712  19365.0000
# 4     -382.8191  1889.2863  19338.1592
# ...         ...        ...         ...
# 5836  -686.8696  -637.3219 -19365.0000
# 5837    70.0221  -934.3800 -19365.0000
# 5838   774.1857  -527.8309 -19365.0000
# 5839   895.3717   276.1856 -19365.0000
# 5840  -926.5345   139.6526 -19365.0000
#
# [5841 rows x 3 columns], (<class 'tuple'>, [(<class 'slice'>, None, None, None), 1])))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 1)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-49eb187b-e973-4b65-82f2-d5e9f4efbe7a'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-7bbc517f-426c-4efd-b279-253f3f0a97f6'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/q3/r96zncz17lq5z2jf1vj44c700000gn/T/ipykernel_60576/934456062.py in <module>
#       6 ### !!!! INVESTIGATE -> NFS / CLUSTER ISSUES ????
#       7
# ----> 8 rotated          = client.gather(rotation_future)
#       9 persisted_rot    = [rotated[i][0].persist() for i in range(len(rotated))]
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    2160             else:
#    2161                 local_worker = None
# -> 2162             return self.sync(
#    2163                 self._gather,
#    2164                 futures,
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/utils.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     309             return future
#     310         else:
# --> 311             return sync(
#     312                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     313             )
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     376     if error:
#     377         typ, exc, tb = error
# --> 378         raise exc.with_traceback(tb)
#     379     else:
#     380         return result
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/utils.py in f()
#     349                 future = asyncio.wait_for(future, callback_timeout)
#     350             future = asyncio.ensure_future(future)
# --> 351             result = yield future
#     352         except Exception:
#     353             error = sys.exc_info()
#
# ~/miniforge3/lib/python3.9/site-packages/tornado/gen.py in run(self)
#     760
#     761                     try:
# --> 762                         value = future.result()
#     763                     except Exception:
#     764                         exc_info = sys.exc_info()
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    2023                             exc = CancelledError(key)
#    2024                         else:
# -> 2025                             raise exception.with_traceback(traceback)
#    2026                         raise exc
#    2027                     if errors == "skip":
#
# ~/miniforge3/lib/python3.9/site-packages/dask/base.py in compute()
#     571         postcomputes.append(x.__dask_postcompute__())
#     572
# --> 573     results = schedule(dsk, keys, **kwargs)
#     574     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     575
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/client.py in get()
#    3008                     should_rejoin = False
#    3009             try:
# -> 3010                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3011             finally:
#    3012                 for f in futures.values():
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/client.py in gather()
#    2160             else:
#    2161                 local_worker = None
# -> 2162             return self.sync(
#    2163                 self._gather,
#    2164                 futures,
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/utils.py in sync()
#     309             return future
#     310         else:
# --> 311             return sync(
#     312                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     313             )
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/utils.py in sync()
#     376     if error:
#     377         typ, exc, tb = error
# --> 378         raise exc.with_traceback(tb)
#     379     else:
#     380         return result
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/utils.py in f()
#     349                 future = asyncio.wait_for(future, callback_timeout)
#     350             future = asyncio.ensure_future(future)
# --> 351             result = yield future
#     352         except Exception:
#     353             error = sys.exc_info()
#
# ~/miniforge3/lib/python3.9/site-packages/tornado/gen.py in run()
#     760
#     761                     try:
# --> 762                         value = future.result()
#     763                     except Exception:
#     764                         exc_info = sys.exc_info()
#
# ~/miniforge3/lib/python3.9/site-packages/distributed/client.py in _gather()
#    2023                             exc = CancelledError(key)
#    2024                         else:
# -> 2025                             raise exception.with_traceback(traceback)
#    2026                         raise exc
#    2027                     if errors == "skip":
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__()
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc()
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#      74         return val in self.mapping
#      75
# ---> 76     cpdef get_loc(self, object val):
#      77         # -> Py_ssize_t | slice | ndarray[bool]
#      78         cdef:
#
# ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#      80
#      81         if is_definitely_invalid_key(val):
# ---> 82             raise TypeError(f"'{val}' is an invalid key")
#      83
#      84         if self.over_size_threshold and self.is_monotonic_increasing:
#
# TypeError: '(slice(None, None, None), 2)' is an invalid key
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-8d88e35f-8458-46b0-b407-fe148870fa4d'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-73eae8fb-e9de-424b-b1c1-ecf8780d5f16'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-a6a610fc-46db-4d5e-8e1d-299376774a6c'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'
#
# distributed.worker - WARNING - Compute Failed
# Function:  compute
# args:      (Delayed('vstack-9af0c92f-edb7-424d-9257-7d6e41399123'))
# kwargs:    {}
# Exception: 'TypeError("\'(slice(None, None, None), 2)\' is an invalid key")'

# %%
mapping_future   = client.map(mapping_single_event, persisted_rot)
mapped           = client.gather(mapping_future)
mapped

# %%
mapped_future    = client.map(dask.compute, mapped)
mapped_computed  = client.gather(mapped_future)
mapped_images    = [mapped_computed[i][0] for i in range(len(mapped_computed))]
mapped_images[0].shape

# %%
ev = 6

image = mapped_images[ev][:,:,0].T
image[image == 0] = np.NaN

fig, ax = plt.subplots(1, figsize=(20,10))
ax.imshow(image)
plt.show()

# %%
client.shutdown()
# Out:
# distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
